# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadNur-123/Feature_transform/blob/main/EathQuake_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/earthquake data.csv")
df.head()
# Out:
#         Date & Time  Latitude  Longitude  Depth  Magnitude     Lands  \
# 0  11/21/2023 17:43    31.592   -104.549      3        2.7   WESTERN
# 1  11/21/2023 17:31   -24.200    -67.580    198        4.0    SALTA,
# 2  11/21/2023 17:27    31.647   -104.017      5        2.9   WESTERN
# 3  11/21/2023 17:01    46.345     13.601      0        0.8  SLOVENIA
# 4  11/21/2023 16:56    -4.320    130.810     10        3.3     BANDA
#
#      Country
# 0      TEXAS
# 1  ARGENTINA
# 2      TEXAS
# 3   SLOVENIA
# 4        SEA

# %%
df = df.rename(columns={'Date & Time': 'Date'})
df.head()
# Out:
#                Date  Latitude  Longitude  Depth  Magnitude     Lands  \
# 0  11/21/2023 17:43    31.592   -104.549      3        2.7   WESTERN
# 1  11/21/2023 17:31   -24.200    -67.580    198        4.0    SALTA,
# 2  11/21/2023 17:27    31.647   -104.017      5        2.9   WESTERN
# 3  11/21/2023 17:01    46.345     13.601      0        0.8  SLOVENIA
# 4  11/21/2023 16:56    -4.320    130.810     10        3.3     BANDA
#
#      Country
# 0      TEXAS
# 1  ARGENTINA
# 2      TEXAS
# 3   SLOVENIA
# 4        SEA

# %%
df.shape
# Out:
# (53539, 7)

# %%
df.isnull().sum()
# Out:
# Date         0
# Latitude     0
# Longitude    0
# Depth        0
# Magnitude    0
# Lands        0
# Country      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53539 entries, 0 to 53538
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       53539 non-null  object
#  1   Latitude   53539 non-null  float64
#  2   Longitude  53539 non-null  float64
#  3   Depth      53539 non-null  int64
#  4   Magnitude  53539 non-null  float64
#  5   Lands      53539 non-null  object
#  6   Country    53539 non-null  object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 2.9+ MB

# %%
df.Country.value_counts()
# Out:
# TURKEY       5797
# REGION       5506
# MEXICO       5450
# INDONESIA    3865
# CHILE        3022
#              ...
# RWANDA          1
# GABON           1
# BISCAY          1
# SLOVAKIA        1
# EGYPT           1
# Name: Country, Length: 187, dtype: int64

# %%
x =df.drop('Magnitude',axis=1)
y = df[['Magnitude']]

# %%
x.head()
# Out:
#                Date  Latitude  Longitude  Depth     Lands    Country
# 0  11/21/2023 17:43    31.592   -104.549      3   WESTERN      TEXAS
# 1  11/21/2023 17:31   -24.200    -67.580    198    SALTA,  ARGENTINA
# 2  11/21/2023 17:27    31.647   -104.017      5   WESTERN      TEXAS
# 3  11/21/2023 17:01    46.345     13.601      0  SLOVENIA   SLOVENIA
# 4  11/21/2023 16:56    -4.320    130.810     10     BANDA        SEA

# %%
y.head()
# Out:
#    Magnitude
# 0        2.7
# 1        4.0
# 2        2.9
# 3        0.8
# 4        3.3

# %%
print('Magnitude in 100%')
round(df.Magnitude.value_counts()*100/len(df),1)
# Out:
# Magnitude in 100%
#  2.0    6.4
#  2.1    6.2
#  2.2    5.3
#  3.0    5.1
#  2.5    4.8
#        ...
#  7.2    0.0
# -0.1    0.0
# -0.2    0.0
# -0.7    0.0
#  7.7    0.0
# Name: Magnitude, Length: 75, dtype: float64

# %% [markdown]
# Viz

# %%
Magnitude =df['Magnitude'].value_counts()
transctions = Magnitude.index
quantity =Magnitude.values
figure =px.pie(df,
               values=quantity,
               names =transctions,hole=.70,
               title="Magnitude")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Country=df['Country'].value_counts()
transctions =Country.index
quantity =Country.values
figure =px.pie(df,
               values=quantity,
               names =transctions,hole=.70,
               title="Country")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Lands=df['Lands'].value_counts()
transctions =Lands.index
quantity =Lands.values
figure =px.pie(df,
               values=quantity,
               names =transctions,hole=.70,
               title="Lands")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# !pip install typing_extensions

# %%
pip install --upgrade typing

# %%
import pandas as pd
from ydata_profiling import ProfileReport
ProfileReport(x, title="Earthquake_Analysis_Report")
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.4&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-01-24 18:18:26.456924&quot;&gt;&lt;title&gt;Earthquake_Analysis_Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
